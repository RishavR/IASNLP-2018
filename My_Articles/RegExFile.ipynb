# %%
import nltk as nlp
import re
x=0
file=open("C-1.xml","r+",encoding="utf8")
text=file.read()
find2= re.finditer(r'^([\w]{3}, [\d]{2} [\w]{3} [\d]{4} [\d]{2}:[\d]{2} [\w]{2} (.....))', text) 
for i in find2:
    replace2= re.sub(r'^([\w]{3}, [\d]{2} [\w]{3} [\d]{4} [\d]{2}:[\d]{2} [\w]{2} (.....))', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' ((अगले \d+ महीने)|(\d+ महीने)|अगले (छह|एक|दो|तीन|चार|पांच|सात|आठ|नौ|दस|ग्यारह|बारह|डेढ़) महीने)', text) 
for i in find2:
    replace2= re.sub(r'(अगले \d+ महीने|(\d+ महीने)| अगले (छह|एक|दो|तीन|चार|पांच|सात|आठ|नौ|दस|ग्यारह|बारह|डेढ़) महीने)', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' ((\d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर) से शुरू होकर \d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|(\d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर) से \d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|(\d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर) \d{4})|(\d+ से \d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|(\d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|\d{4} से \d{4}|\d{4} के बाद|\d{4}|साल \d{4}|इसी साल)', text) 
for i in find2:
    replace2= re.sub(r'((\d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर) से शुरू होकर \d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|(\d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर) से \d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|(\d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर) \d{4})|(\d+ से \d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|(\d+ (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|\d{4} से \d{4}|\d{4} के बाद|\d{4}|साल \d{4}|इसी साल)', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (\d+(दिनों|दिन)|(कुछ|चंद) दिनों)', text) 
for i in find2:
    replace2= re.sub(r'((\d+ (दिनों|दिन)| (कुछ|चंद) दिनों))', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (आज | परसों | कल)', text) 
for i in find2:
    replace2= re.sub(r'(आज | परसों | कल )', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (((तीन|दो|एक) (साल|दिन) पहले)|((तीन|दो|एक|इस) (साल|दिन)))', text) 
for i in find2:
    replace2= re.sub(r'(((तीन|दो|एक) (साल|दिन) पहले)|((तीन|दो|एक|इस) (साल|दिन)))', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (बीस दिन आगे)', text) 
for i in find2:
    replace2= re.sub(r'(बीस दिन आगे)', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (लंबे समय| समय)', text) 
for i in find2:
    replace2= re.sub(r'(लंबे समय | समय)', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (((अगले|पिछले) \d+ साल)|((अगले|पिछले) (महीने|साल|सप्ताह|हफ्ते) (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|((अगले|पिछले) (महीने|साल|सप्ताह|हफ्ते)))', text) 
for i in find2:
    replace2= re.sub(r'(((अगले|पिछले) \d+ साल)|((अगले|पिछले) (महीने|साल|सप्ताह|हफ्ते) (जनवरी|फरवरी|मार्च|अप्रैल|मई|जून|जुलाई|अगस्त|सितंबर|अक्टूबर|नवंबर|दिसंबर))|((अगले|पिछले) (महीने|साल|सप्ताह|हफ्ते)))', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' ((डेढ़ महीने))', text) 
for i in find2:
    replace2= re.sub(r'((डेढ़ महीने))', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (\d+ से \d+( साल | महीने | दिनों|दिन))|\d+ साल', text) 
for i in find2:
    replace2= re.sub(r'(\d+ से \d+( साल | महीने | दिनों|दिन))|\d+ साल', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (रोज)', text) 
for i in find2:
    replace2= re.sub(r'(रोज)', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (पहले दिन सोमवार)|(पहले दिन)', text) 
for i in find2:
    replace2= re.sub(r'(पहले दिन सोमवार)|(पहले दिन)', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' महीने भर', text) 
for i in find2:
    replace2= re.sub(r'(महीने भर)', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (गर्मियों|सर्दियों )', replace2) 
for i in find2:
    replace2= re.sub(r'(गर्मियों |सर्दियों )', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (समय )', text) 
for i in find2:
    replace2= re.sub(r'(समय )', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (((रविवार|सोमवार|मंगलवार|बुधवार|गुरूवार|बृहस्पतिवार|शुक्रवार|शनिवार) दिन भर)|(रविवार|सोमवार|मंगलवार|बुधवार|गुरूवार|बृहस्पतिवार|शुक्रवार|शनिवार))', text) 
for i in find2:
    replace2= re.sub(r'(((रविवार|सोमवार|मंगलवार|बुधवार|गुरूवार|बृहस्पतिवार|शुक्रवार|शनिवार) दिन भर)|(रविवार|सोमवार|मंगलवार|बुधवार|गुरूवार|बृहस्पतिवार|शुक्रवार|शनिवार))',r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (समय )', text) 
for i in find2:
    replace2= re.sub(r'(समय )', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
find2= re.finditer(r' (समय )', text) 
for i in find2:
    replace2= re.sub(r'(समय )', r'<T>\1</T>', text) 
    print(i.group())
    x=x+1
print(replace2)
print(x)
# Out:
#  अगले 6 महीने
#  26 फरवरी
#  3 फरवरी
#  1612
# ﻿<?xml version="1.0" encoding="UTF-8" ?>
# <DOC><TEXT>
# ...
